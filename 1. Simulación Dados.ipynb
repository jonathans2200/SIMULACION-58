# %%
from collections import Counter
import json
res=[]
suma=0
for i in range(6):
    for j in range(6):
        suma=(i+1)+(j+1)
        res.append(suma)
c=Counter(res)
for i in sorted(c.items()):
    print("Valor: ", i[0] , " Porcentaje: ",round((i[1]/11)*100,2), " %")
# Out:
# Valor:  2  Porcentaje:  9.09  %
# Valor:  3  Porcentaje:  18.18  %
# Valor:  4  Porcentaje:  27.27  %
# Valor:  5  Porcentaje:  36.36  %
# Valor:  6  Porcentaje:  45.45  %
# Valor:  7  Porcentaje:  54.55  %
# Valor:  8  Porcentaje:  45.45  %
# Valor:  9  Porcentaje:  36.36  %
# Valor:  10  Porcentaje:  27.27  %
# Valor:  11  Porcentaje:  18.18  %
# Valor:  12  Porcentaje:  9.09  %

# %%
from collections import Counter
import json
import random
import matplotlib.pyplot as plt
resultado=[]
def calcular(num):
    for i in range(num):
        dado1= random.randint(1, 6)
        dado2= random.randint(1, 6)
        resultado.append(dado1+dado2)
    val=Counter(resultado)
    print(json.dumps(val,indent=2,sort_keys=True))
    plt.title('Histograma para '+ str(num) +' valores')
    plt.hist(resultado,bins=num, width=0.5, alpha=0.7, edgecolor = 'black')
    plt.grid(axis='y', alpha=0.75)
    plt.xlabel('Valor',fontsize=15)
    plt.ylabel('Frequencia',fontsize=15)
    plt.xticks(range(0, max(val.keys())+1))
    plt.show()
    for i in sorted(val.items()):
        print("Valor: ", i[0] , " Porcentaje: ",round((i[1]/num)*100,2), " %")

# %%
calcular(100)
# Out:
# {
#   "2": 1,
#   "3": 7,
#   "4": 10,
#   "5": 13,
#   "6": 12,
#   "7": 14,
#   "8": 7,
#   "9": 9,
#   "10": 16,
#   "11": 6,
#   "12": 5
# }
# Valor:  2  Porcentaje:  1.0  %
# Valor:  3  Porcentaje:  7.0  %
# Valor:  4  Porcentaje:  10.0  %
# Valor:  5  Porcentaje:  13.0  %
# Valor:  6  Porcentaje:  12.0  %
# Valor:  7  Porcentaje:  14.0  %
# Valor:  8  Porcentaje:  7.0  %
# Valor:  9  Porcentaje:  9.0  %
# Valor:  10  Porcentaje:  16.0  %
# Valor:  11  Porcentaje:  6.0  %
# Valor:  12  Porcentaje:  5.0  %

# %%
calcular(1000)
# Out:
# {
#   "2": 15,
#   "3": 65,
#   "4": 99,
#   "5": 120,
#   "6": 149,
#   "7": 181,
#   "8": 133,
#   "9": 137,
#   "10": 106,
#   "11": 59,
#   "12": 36
# }
# Valor:  2  Porcentaje:  1.5  %
# Valor:  3  Porcentaje:  6.5  %
# Valor:  4  Porcentaje:  9.9  %
# Valor:  5  Porcentaje:  12.0  %
# Valor:  6  Porcentaje:  14.9  %
# Valor:  7  Porcentaje:  18.1  %
# Valor:  8  Porcentaje:  13.3  %
# Valor:  9  Porcentaje:  13.7  %
# Valor:  10  Porcentaje:  10.6  %
# Valor:  11  Porcentaje:  5.9  %
# Valor:  12  Porcentaje:  3.6  %

# %%
calcular(10000)
# Out:
# {
#   "2": 309,
#   "3": 576,
#   "4": 951,
#   "5": 1234,
#   "6": 1499,
#   "7": 1884,
#   "8": 1450,
#   "9": 1324,
#   "10": 942,
#   "11": 613,
#   "12": 318
# }
# Valor:  2  Porcentaje:  3.09  %
# Valor:  3  Porcentaje:  5.76  %
# Valor:  4  Porcentaje:  9.51  %
# Valor:  5  Porcentaje:  12.34  %
# Valor:  6  Porcentaje:  14.99  %
# Valor:  7  Porcentaje:  18.84  %
# Valor:  8  Porcentaje:  14.5  %
# Valor:  9  Porcentaje:  13.24  %
# Valor:  10  Porcentaje:  9.42  %
# Valor:  11  Porcentaje:  6.13  %
# Valor:  12  Porcentaje:  3.18  %
